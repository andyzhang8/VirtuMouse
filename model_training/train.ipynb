# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.train(data='D:\VirtuMouse\data\data.yaml', epochs=500, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.163 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.143  Python-3.10.12 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
